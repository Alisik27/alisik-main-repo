# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 25.01.2026
#
# Мягкий дедлайн: 23:59MSK 08.02.2026
#
# Жесткий дедлайн: 23:59MSK 14.02.2026

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки `pandas` и визуализации с помощью `matplotlib`. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
#
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов без учета бонуса. Сдавать задание после жёсткого дедлайна нельзя.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Устная проверка. Для проверки понимания кода и выводов студент может быть приглашён на устную защиту. Оценка за задание может быть изменена после устной защиты. Если студент не может объяснить ключевые части решения и принятые решения, работа считается недобросовестной и оценивается в 0 баллов независимо от автотестов.
#
# ### Формат сдачи
#
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате `homework-practice-01-pandas-Username.ipynb`, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: 10

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками используется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code
print("panda?")
# Out:
# panda?

# %%
print("panda! " * 5 + "not panda")
# Out:
# panda! panda! panda! panda! panda! not panda

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидите много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно

# %% [markdown]
# ### Kaggle
#
# Альтернативой является **Kaggle**, он же площадка для самых разных соревнований по машинному обучению
#
# Он, как и колаб, предоставляет бесплатный GPU, и даже не один, с чётким лимитом в 30 часов в неделю (colab может его внезапно отобрать, kaggle - нет) более мощные CPU с большим числом ядер, и больше Гб ОЗУ (раз так в 2.5)
#
# https://www.kaggle.com
#
# К сожалению мир не идеален, недостатки следующие:
# - необходимость загружать датасеты через специальную кнопочку
# - невозможность использовать свои скрипты и модули :(
# - нужно тыкать техподдержку, чтобы создать аккаунт из России

# %% [markdown]
# ## 1. Табличные данные и Pandas [4 балла]

# %% [markdown]
# Pandas - удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в `pandas` - это `pd.DataFrame`, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и StackOverflow.

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <span style="color:red">Перед выполнением задания необходимо ознакомиться с первым семинаром (seminars/sem01-pandas.ipynb) </span>.
#
# Это поможет вам получить общее понимание происходящего и успешнее справиться с заданием.
#
# Также успешному выполнению способствует внимательное чтение текста задания от начала до конца.
#
# Удачи!

# %% [markdown]
# Скачаем подготовленные на семинаре данные:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/scl/fi/2ezfw6b3y1umremflbgdl/end_seminar.xlsx?rlkey=xzecol82ybnpu0eon0b1s11pp&st=f45sugvp&dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
#!powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
import wget
wget.download('https://www.dropbox.com/scl/fi/2ezfw6b3y1umremflbgdl/end_seminar.xlsx?rlkey=xzecol82ybnpu0eon0b1s11pp&st=f45sugvp&dl=0', 'end_seminar.xlsx')
# Out:
# ...
# 'end_seminar (2).xlsx'

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") запрещены циклы (`for`, `while`) и построчные преобразования: `apply`/`applymap`, `map`, `assign` с `lambda`, `np.vectorize`, `np.apply_along_axis` и аналогичные конструкции. Нарушение этого правила повлечёт снижение оценки. Используйте векторные операции и стандартные методы pandas.

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0.5 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите 3 последних строки.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
df = pd.read_excel('end_seminar.xlsx')
df.tail(3)
# Out:
#                   timestamp  \
# 426 2024-08-19 11:49:43.000
# 427 2024-08-13 14:58:30.000
# 428 2024-08-13 18:35:25.235
#
#                                                     id  rating  group_22  \
# 426  77b2b19d26b7f160c1938369197f7cac590b2e0cfcac3b...    1232       NaN
# 427  6dafd9a56d08aeb419166d314b0cd6f3107ae5e8dbd636...     961       NaN
# 428  4bf710d7b89064e1a3cbcc69b7ca67c20d6181dc72ad35...    1374       NaN
#
#      is_mi                                             fall_1  \
# 426    NaN  Принятие решений в условиях риска и неопределе...
# 427    NaN                      Основы информационного поиска
# 428    NaN            Трансформерные и мультимодальные модели
#
#                                       fall_2                       fall_3  \
# 426       Основы разработки компьютерных игр  Введение в платформы данных
# 427                            Дизайн систем  Язык программирования Scala
# 428  Глубинное обучение для текстовых данных     Self-supervised Learning
#
# ...

# %% [markdown]
# ### Ответьте на вопросы:
# 1. Сколько было уникальных пользователей из групп 22-го года набора, а сколько из групп 21-го года?

# %%
unique_21 = len(df.loc[df['group_21'].notna(), 'id'].unique())
unique_22 = len(df.loc[df['group_22'].notna(), 'id'].unique())
print(f'Уникальных пользователей из групп 21-го года набора: {unique_21}')
print(f'Уникальных пользователей из групп 22-го года набора: {unique_22}')
# Out:
# Уникальных пользователей из групп 21-го года набора: 159
# Уникальных пользователей из групп 22-го года набора: 259

# %% [markdown]
# 2. Есть ли среди объединенного множества 3-го и 4-го курса уникальные студенты с равными перцентилями?

# %%
df_unique = df.drop_duplicates(subset=['id'])
if df_unique.percentile.nunique() == df_unique.shape[0]:
  print('Нет уникальных студентов с равными перцентилями')
else:
  print('Есть уникальные студенты с равными перцентилями')
# Out:
# Есть уникальные студенты с равными перцентилями

# %% [markdown]
# #### 2. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
print('Информация о пропусках по колонкам:')
df.isna().sum()
# Out:
# Информация о пропусках по колонкам:
# timestamp          0
# id                 0
# rating             0
# group_22         159
# is_mi            403
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1          48
# spring_2          48
# spring_3          48
# is_first_time      0
# percentile         0
# group_21         270
# blended          270
# is_ml_student    254
# dtype: int64

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок, нулём для числовых и False для булевых (постарайтесь избежать перечисления названий всех столбцов). Опирайтесь не на смысл столбцов, а на текущий тип данных.

# %% [markdown]
# Посмотрим, какие вообще типы данных у нас есть:

# %%
df.dtypes
# Out:
# timestamp        datetime64[ns]
# id                       object
# rating                    int64
# group_22                float64
# is_mi                   float64
# fall_1                   object
# fall_2                   object
# fall_3                   object
# spring_1                 object
# spring_2                 object
# spring_3                 object
# is_first_time            object
# percentile              float64
# group_21                float64
# blended                  object
# is_ml_student           float64
# dtype: object

# %%
numeriс_data = df.select_dtypes(include=['int64', 'float64']).columns
string_data = df.select_dtypes(include=['object']).columns
bool_data = df.select_dtypes(include=['bool']).columns
df[numeriс_data] = df[numeriс_data].fillna(value=0)
df[string_data] = df[string_data].fillna(value='')
df[bool_data] = df[bool_data].fillna(value=False)

# %% [markdown]
# Проверим, что теперь пропусков в данных не осталось:

# %%
df.isna().sum()
# Out:
# timestamp        0
# id               0
# rating           0
# group_22         0
# is_mi            0
# fall_1           0
# fall_2           0
# fall_3           0
# spring_1         0
# spring_2         0
# spring_3         0
# is_first_time    0
# percentile       0
# group_21         0
# blended          0
# is_ml_student    0
# dtype: int64

# %% [markdown]
# #### 3. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Каково процентное соотношение ответов? Сколько из них "Нет"?

# %%
proportion = 100 * df.is_first_time.value_counts(normalize=True)
print(proportion)
# Out:
# is_first_time
# Да     94.871795
# Нет     5.128205
# Name: proportion, dtype: float64

# %%
cnt = (df['is_first_time'] == "Нет").sum()
print(f'Количество ответов "Нет": {cnt}')
# Out:
# Количество ответов "Нет": 22

# %% [markdown]
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. В дальнейших заданиях используйте версию данных без повторов. Уберите колонку is_mi, она нам не пригодится
#
# <i>Обращения со значением "Нет" в 'is_first_time' могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
df_sorted = df.sort_values(by = ['id', 'timestamp'], ascending=[True, False])
df_unique_new = df_sorted.drop_duplicates(subset=['id'], keep='first')
df_unique_new = df_unique_new.reset_index(drop=True)
del df_unique_new['is_mi']

# %% [markdown]
# Посмотрим, что у нас получилось:

# %%
df_unique_new.head()
# Out:
#             timestamp                                                 id  \
# 0 2024-08-13 21:27:21  0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1 2024-08-14 10:27:31  01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 2 2024-08-13 18:16:33  01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...
# 3 2024-08-14 15:18:51  027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...
# 4 2024-08-13 19:26:10  0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
#
#    rating  group_22                                fall_1  \
# 0     522     229.0                    Системы баз данных
# 1    1030       0.0  Глубинное обучение в обработке звука
# 2     494     223.0           Statistical Learning Theory
# 3     696     222.0        Разработка микросервисов на Go
# 4     547     225.0                Распределенные системы
#
#                              fall_2                                   fall_3  \
# 0                Системы баз данных                       Системы баз данных
# ...

# %% [markdown]
# #### 4. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из blended-курсов наименьший средний перцентиль студентов, подавших заявку (выведите этот курс и количество студентов на нем)?

# %%
blended_courses = df_unique_new['blended'].unique()

print("Список blended-курсов: ")
for i in blended_courses:
    if (i != ''):
      print(i)
# Out:
# Список blended-курсов:
# ML System Design
# Соревновательный анализ данных
# Безопасность систем на базе LLM
# Протоколы доказательств с нулевым разглашением
# Введение в дифференциальную геометрию
# Продуктовый подход к анализу данных

# %% [markdown]
# Посмотрим, на какие blended-курсы сколько человек записалось:

# %%
blended_courses_df = df['blended'].value_counts()

# %%
blended_courses_df
# Out:
# blended
#                                                   270
# Протоколы доказательств с нулевым разглашением     44
# ML System Design                                   38
# Соревновательный анализ данных                     26
# Продуктовый подход к анализу данных                25
# Безопасность систем на базе LLM                    13
# Введение в дифференциальную геометрию              13
# Name: count, dtype: int64

# %% [markdown]
# Так как value_counts() по умолчанию сортирует по убыванию значений, чтобы найти самый популярный курс, можем просто взять первую строчку

# %%
blended_courses_df.iloc[1:2]
# Out:
# blended
# Протоколы доказательств с нулевым разглашением    44
# Name: count, dtype: int64

# %% [markdown]
# Таким образом, наиболее популярный blended-курс - "Протоколы доказательств с нулевым разглашением" (44 чел)

# %%
df1 = df_unique_new

# %%
df2 = df1[df1['blended'] != ''].groupby('blended')['percentile'].mean().sort_values()

# %%
df2
# Out:
# blended
# Продуктовый подход к анализу данных               0.391950
# Соревновательный анализ данных                    0.462385
# ML System Design                                  0.470953
# Безопасность систем на базе LLM                   0.531930
# Протоколы доказательств с нулевым разглашением    0.563250
# Введение в дифференциальную геометрию             0.583454
# Name: percentile, dtype: float64

# %% [markdown]
# Курс с наименьшим средним перцентилем:

# %%
df2.iloc[0:1]
# Out:
# blended
# Продуктовый подход к анализу данных    0.39195
# Name: percentile, dtype: float64

# %%
print(f'Количество студентов на курсе: {blended_courses_df.loc['Продуктовый подход к анализу данных']}')
# Out:
# Количество студентов на курсе: 25

# %% [markdown]
# #### 5. [1 балл] Выясните, есть ли студенты с абсолютно одинаковыми предпочтениями по всем курсам.
#
# Для этого сформируйте таблицу, где для каждого возможного набора курсов посчитано количество студентов, выбравших такой набор, и оставьте только строки где это количество больше 1. Формировать варианты, которые не представлены ни одним студентом изначально, не требуется.
#
# В данном случае набор курсов задается упорядоченным множеством ('fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'). Элемент blended будет нулевым для 3-го курса.

# %%
cols = ['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']
groups = df1.groupby(cols)

# %% [markdown]
# Посмотрим, что пока выходит:

# %%
df_courses = df1.groupby(cols).size().reset_index(name='Кол-во студентов')
df_courses
# Out:
#                           fall_1  \
# 0       Self-supervised Learning
# 1       Self-supervised Learning
# 2       Self-supervised Learning
# 3       Self-supervised Learning
# 4       Self-supervised Learning
# ..                           ...
# 389                     Язык SQL
# 390                     Язык SQL
# 391                     Язык SQL
# 392                     Язык SQL
# 393  Язык программирования Scala
#
#                                                 fall_2  \
# 0               Байесовские методы в машинном обучении
# 1                     Безопасность компьютерных систем
# 2    Генеративные модели на основе диффузии / Diffu...
# 3    Генеративные модели на основе диффузии / Diffu...
# 4    Генеративные модели на основе диффузии / Diffu...
# ..                                                 ...
# 389                                 Системы баз данных
# 390                                 Системы баз данных
# 391                                           Язык SQL
# ...

# %% [markdown]
# Уберем лишние строки:

# %%
df3 = df_courses[df_courses['Кол-во студентов'] > 1]
df3
# Out:
#                                fall_1                              fall_2  \
# 13        Statistical Learning Theory       Основы информационного поиска
# 60   Безопасность компьютерных систем  Основы разработки компьютерных игр
# 134                     Дизайн систем    Безопасность компьютерных систем
# 135                     Дизайн систем    Безопасность компьютерных систем
# 142                     Дизайн систем              Операционные системы 2
# 282                Системы баз данных              Операционные системы 2
# 288                Системы баз данных              Операционные системы 2
# 290                Системы баз данных              Операционные системы 2
# 293                Системы баз данных              Операционные системы 2
# 309                Системы баз данных      Разработка микросервисов на Go
# 311                Системы баз данных      Разработка микросервисов на Go
# 313                Системы баз данных      Разработка микросервисов на Go
# ...

# %% [markdown]
# Таким образом, студенты с абсолютно одинаковыми предпочтениями действительно есть

# %% [markdown]
# #### 6. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 22-го года набора, так и студенты 21-го года.

# %%
is_in_group_21 = df1[df1['group_21'] != 0]
is_in_group_22 = df1[df1['group_22'] != 0]
courses_cols = ['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']
for_21 = set(is_in_group_21[courses_cols].melt()['value']) #уникальное множ-во курсов, которые выбирали group_21

# %%
for_22 = set(is_in_group_22[courses_cols].melt()['value'])  #уникальное множ-во курсов, которые выбирали group_22

# %%
common_courses = for_21 & for_22

# %% [markdown]
# Список курсов, общих для group_21 и group_22:

# %%
common_courses
# Out:
# {'Statistical Learning Theory',
#  'Безопасность компьютерных систем',
#  'Введение в платформы данных',
#  'Интегральные уравнения в задачах математического моделирования',
#  'Математические основы нейросетевых моделей',
#  'Операционные системы 2',
#  'Основы информационного поиска',
#  'Основы разработки компьютерных игр',
#  'Основы тензорных вычислений',
#  'Принятие решений в условиях риска и неопределенности',
#  'Специальные разделы матричного анализа',
#  'Стохастический анализ',
#  'Типы в языках программирования',
#  'Язык программирования Scala'}

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 22-го года и только студентам 21-го года.

# %%
only_21 = for_21.difference(common_courses)
only_22 = for_22.difference(common_courses)
only_22.remove('')

# %%
only_21
# Out:
# {'ML System Design',
#  'Self-supervised Learning',
#  'Байесовские методы в машинном обучении',
#  'Безопасность систем на базе LLM',
#  'Введение в дифференциальную геометрию',
#  'Генеративные модели в машинном обучении',
#  'Генеративные модели на основе диффузии',
#  'Генеративные модели на основе диффузии / Diffusion-Based Generative Models',
#  'Глубинное обучение в анализе графовых данных',
#  'Глубинное обучение в обработке звука',
#  'Глубинное обучение для текстовых данных',
#  'Децентрализованные системы',
#  'Дизайн систем',
#  'Конфликты и кооперация (преподается на английском языке)',
#  'Методы сжатия и передачи медиаданных',
#  'Обучение с подкреплением',
#  'Продуктовый подход к анализу данных',
#  'Промышленное программирование на Haskell',
#  'Протоколы доказательств с нулевым разглашением',
#  'Развёртывание ML-моделей в высоконагруженных системах',
#  'Символьные вычисления',
#  'Современные языковые модели',
#  'Соревновательный анализ данных',
# ...

# %%
only_22
# Out:
# {'Go от шада',
#  'Аналитика данных',
#  'Генеративные модели в машинном обучении (углубленный курс)',
#  'Глубинное обучение в естественных науках',
#  'Дополнительные главы машинного обучения',
#  'Количественные финансы',
#  'Комбинаторная оптимизация',
#  'Компьютерные сети',
#  'Лингвистика для программистов',
#  'Машинное обучение 2',
#  'Машинное обучение в прикладных задачах',
#  'Моделирование временных рядов',
#  'Прикладная статистика в машинном обучении',
#  'Промышленное программирование на языке Java',
#  'Разработка микросервисов на Go',
#  'Распределенные системы',
#  'Рекомендательные системы',
#  'Системы баз данных',
#  'Топологический анализ данных',
#  'Функциональное программирование',
#  'ШАД RL',
#  'Шадовский Go',
#  'Язык SQL',
#  'Язык программирования Go'}

# %% [markdown]
# Видите ли вы что-то необычное в получившихся списках? (менять ничего не нужно, просто подумайте)
#
# **Ответ:** Один и тот же курс существует с двумя разными названиями: "Go от шада" и "Шадовский Go"

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Еще одна библиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html) (обычно сокращается до sns). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
#
# **5 пунктов после которых ваши графики не будут прежними:**
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>plt.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>
#
# Добавьте эти функции в ячейку ниже. Каждый график все равно придется настраивать отдельно, но указанные строчки позволят значительно упростить процесс.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['font.size'] = 12
plt.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')

# %% [markdown]
# #### 7. [0.5 балла] Постройте график (barplot) медианных перцентилей в зависимости от первого символа hex-кода id студента
#
# Таким образом мы на глаз прикидываем, есть ли зависимость между, якобы, случайным id и значимым параметром. Если зависимость есть, и в дальнейшем мы будем сплитовать данные на тест и трейн по такому айдишнику без перемешивания, то можем допустить утечку, поэтому такие особенности важно отслеживать.
#
# В графике явно задайте порядок столбцов по символам hex-алфавита (от 0 до f слева направо) и настройте отображение доверительных интервалов уровня **0.96**. Можно ли говорить о наличии проверяемой зависимости на основе визуальной информации?

# %%
import numpy as np
df1['hex_char'] = df1['id'].str[0]

ax = sns.barplot(
    data=df1,
    x='hex_char',
    y='percentile',
    hue = 'hex_char',
    estimator=np.median,
    errorbar=('ci', 0.96),
    palette='PiYG',

)
plt.title('Зависимость медианных перцентилей от первого символа ID студента')
plt.tight_layout()

# %% [markdown]
# На первый взгляд четкой зависимости между первым символом ID и перцентилем студента не наблюдается

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
plt.savefig('percentile_by_id_char')

# %% [markdown]
# ## 2. Распределение студентов по курсам. (6 баллов + один бонусный балл)

# %% [markdown]
# #### **<span style="color:red">‼️ВНИМАТЕЛЬНО ИЗУЧИТЕ ТЕКСТ НИЖЕ‼️</span>.**
#
# <span style="color:orange">Если во время выполнения заданий у вас возникнут вопросы - еще раз перечитайте текст целиком, скорее всего ответы уже содержатся в нем.</span>
#
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# ## **Алгоритм распределения студентов по курсам**:
#
# 1. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест (см ниже), то выбирается топ по перцентилю рейтинга.
# 2. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентилю рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 3. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# ## ☝️ **Обращаем ваше внимание на следующие детали:**

# %% [markdown]
# ### Особенности реализации алгоритма:
#
# - Конкурс на каждый курс общий для 3-го (22-й год) и 4-го курса (21-й год), то есть список формируется из студентов обоих курсов.
#
# - По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов).
#   - Исключения:
#     * Количественные финансы - 60
#     * Промышленное программирование на Haskell - 60
#     * Рекомендательные системы - 60
#     * Глубинное обучение в обработке звука - 1000 (да да, не удивляйтесь! раньше и не такое было...)
#
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп **21-го года специализации МОП** выбирают по 2 осенних и 2 весенних курса по выбору. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются.
#   - "Сдвиг" = приоритеты 2 и 3 становятся приоритетами 1 и 2, 3-й приоритет остается пустым.
#   - Из-за совпадений первого и второго курса по выбору в прочих случаях двигать приоритеты не надо.
#
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - В рамках своего решения вы можете считать, что в процессе распределения не возникнет ситуации, когда на одно место претендуют студенты с одинаковым перцентилем.

# %% [markdown]
# ### Я МОП и я люблю <s>Я</s>
#
#
#
# **Принадлежность к <s> стойлу</s> специализации МОП определяется так:**
#
# - 21-й год (4-й курс):
#   * 211, 212, 213 - МОП; остальные - не МОП! 👎
#
# - 22-й год (3-й курс)
#   -  Студенты, у которых проставлен флаг в колонке `is_ml_student`.

# %% [markdown]
# ### Рейтинг и перцентиль
#
# #### Рейтинг
#
# В столбце `'rating'` записана кредитно-рейтинговая сумма студента (грубо говоря, сумма оценок студента по всем его дисциплинам с весами (веса > 1) — чем дольше шла дисциплина, тем больше вес; подробности тут: https://www.hse.ru/studyspravka/rate/).
#
# Чем больше курсов взял студент за период обучения, и чем лучше он их закрыл, тем выше его значение `'rating'`, соответственно, эта метрика возрастает по "качеству" студента.
#
# #### Перцентиль
#
# В столбце `'percentile'` записан перцентиль студента в рамках своего курса своей ОП.
#
# Перцентиль студента X определяется следующим образом: "процент студентов, чьи результаты обучения лучше, чем у студента X". Соответственно, 0% -- лучший студент на потоке, $\to$ 100% -- худший студент на потоке, то есть метрика убывает по "качеству" студента.
#
#
# Мы распределяем студентов по топу перцентиля, то есть по наименьшему перцентилю.
#
#
# За прочими подробностями отправляем вас в ноутбук семинара.

# %% [markdown]
# ### Требования к решению
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i> Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись без цикла по курсам, то можете получить **+1 бонусный балл** к итоговой оценке. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл `res_fall.csv` с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * три столбца: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * Формат csv: для сохранения воспользуйтесь `df.to_csv("res_fall.csv", index=False)`

# %% [markdown]
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/scl/fi/2ezfw6b3y1umremflbgdl/end_seminar.xlsx?rlkey=xzecol82ybnpu0eon0b1s11pp&st=f45sugvp&dl=0)
#
#
# Кстати, убедитесь, что в данных больше нет пропусков, повторных записей и лишних колонок

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
df = df1.drop(columns='hex_char')

# %%
df
# Out:
#                   timestamp  \
# 0   2024-08-13 21:27:21.000
# 1   2024-08-14 10:27:31.000
# 2   2024-08-13 18:16:33.000
# 3   2024-08-14 15:18:51.000
# 4   2024-08-13 19:26:10.000
# ..                      ...
# 413 2024-08-13 22:56:34.000
# 414 2024-08-14 21:37:11.000
# 415 2024-08-14 22:39:30.429
# 416 2024-08-14 14:42:14.000
# 417 2024-08-14 19:07:26.000
#
#                                                     id  rating  group_22  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...     522     229.0
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...    1030       0.0
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...     494     223.0
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...     696     222.0
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...     547     225.0
# ..                                                 ...     ...       ...
# 413  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...     650     229.0
# ...

# %%
assert df.shape == (418, 15), 'В таблице остались повторы или потеряны данные'
assert df.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе студента.

# %%
df['courses_quantity'] = 1
df.loc[df['group_21'].isin([211, 212, 213]) , 'courses_quantity'] = 2

# %%
df
# Out:
#                   timestamp  \
# 0   2024-08-13 21:27:21.000
# 1   2024-08-14 10:27:31.000
# 2   2024-08-13 18:16:33.000
# 3   2024-08-14 15:18:51.000
# 4   2024-08-13 19:26:10.000
# ..                      ...
# 413 2024-08-13 22:56:34.000
# 414 2024-08-14 21:37:11.000
# 415 2024-08-14 22:39:30.429
# 416 2024-08-14 14:42:14.000
# 417 2024-08-14 19:07:26.000
#
#                                                     id  rating  group_22  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...     522     229.0
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...    1030       0.0
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...     494     223.0
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...     696     222.0
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...     547     225.0
# ..                                                 ...     ...       ...
# 413  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...     650     229.0
# ...

# %% [markdown]
# Проверка:

# %%
col_name = 'courses_quantity' # insert your new column name as str

assert(df[df['id'] == 'bcca318e644999583156ff3ab9de3d6bd02295dcb166e39006568ffe9582207b'][col_name] == 1).all()
assert(df[df['id'] == 'edb64996c64421378537d941a77426a5a7bd84f9967ad9f523ca61386e5469ed'][col_name] == 1).all()
assert(df[df['id'] == '5f96908e3ce5d84d693ddd79670d60cd1c6a02646aa779f46586a7699dda7c25'][col_name] == 1).all()
assert(df[df['id'] == '0f137538a170b64258c0e10839cadc325e5f22fc5bb5fa9e20b7351f0a680366'][col_name] == 2).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
fall_cols = ['fall_1', 'fall_2', 'fall_3']
spring_cols = ['spring_1', 'spring_2', 'spring_3']
cols = ['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3']
fall_courses = set(df[fall_cols].melt()['value'])
spring_courses = set(df[spring_cols].melt()['value'])
spring_courses.remove('')

courses = df[cols].melt()
courses = set(df[cols].melt()['value'])

# %%
fall_courses
# Out:
# {'Self-supervised Learning',
#  'Statistical Learning Theory',
#  'Байесовские методы в машинном обучении',
#  'Безопасность компьютерных систем',
#  'Введение в платформы данных',
#  'Генеративные модели на основе диффузии',
#  'Генеративные модели на основе диффузии / Diffusion-Based Generative Models',
#  'Глубинное обучение в анализе графовых данных',
#  'Глубинное обучение в обработке звука',
#  'Глубинное обучение для текстовых данных',
#  'Дизайн систем',
#  'Интегральные уравнения в задачах математического моделирования',
#  'Операционные системы 2',
#  'Основы информационного поиска',
#  'Основы разработки компьютерных игр',
#  'Основы тензорных вычислений',
#  'Прикладная статистика в машинном обучении',
#  'Принятие решений в условиях риска и неопределенности',
#  'Разработка микросервисов на Go',
#  'Распределенные системы',
#  'Системы баз данных',
#  'Теория сложных систем',
#  'Типы в языках программирования',
#  'Трансформерные и мультимодальные модели',
# ...

# %%
spring_courses
# Out:
# {'Go от шада',
#  'Аналитика данных',
#  'Генеративные модели в машинном обучении',
#  'Генеративные модели в машинном обучении (углубленный курс)',
#  'Глубинное обучение в естественных науках',
#  'Децентрализованные системы',
#  'Дополнительные главы машинного обучения',
#  'Количественные финансы',
#  'Комбинаторная оптимизация',
#  'Компьютерные сети',
#  'Конфликты и кооперация (преподается на английском языке)',
#  'Лингвистика для программистов',
#  'Математические основы нейросетевых моделей',
#  'Машинное обучение 2',
#  'Машинное обучение в прикладных задачах',
#  'Методы сжатия и передачи медиаданных',
#  'Моделирование временных рядов',
#  'Обучение с подкреплением',
#  'Промышленное программирование на Haskell',
#  'Промышленное программирование на языке Java',
#  'Развёртывание ML-моделей в высоконагруженных системах',
#  'Рекомендательные системы',
#  'Символьные вычисления',
#  'Современные языковые модели',
#  'Специальные разделы матричного анализа',
# ...

# %%
fall_melted_df = df[['id', 'courses_quantity', 'fall_1', 'fall_2', 'fall_3']].melt(
    id_vars=['id', 'courses_quantity'],
    value_vars=['fall_1', 'fall_2', 'fall_3'],
    var_name='fall_position',
    value_name='course_name'
)

# %%
fall_melted_df
# Out:
#                                                      id  courses_quantity  \
# 0     0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...                 1
# 1     01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...                 2
# 2     01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...                 1
# 3     027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...                 1
# 4     0371f1e9746b55e981d200dbc94929d95e6629295cbe43...                 1
# ...                                                 ...               ...
# 1249  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...                 1
# 1250  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...                 1
# 1251  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...                 1
# 1252  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...                 1
# 1253  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...                 1
#
#      fall_position                           course_name
# ...

# %%
first_priority = (
    (fall_melted_df['fall_position'] == 'fall_1') |
    ((fall_melted_df['fall_position'] == 'fall_2') & (fall_melted_df['courses_quantity'] == 2))
)

# %%
fall_melted_first_pr_df =  fall_melted_df[first_priority].dropna(subset=['course_name'])

# %%
fall_melted_first_pr_df
# Out:
#                                                     id  courses_quantity  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...                 1
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...                 2
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...                 1
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...                 1
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...                 1
# ..                                                 ...               ...
# 809  f0be509325f2e4dde7f85e32621a357db8dbd07522142f...                 2
# 813  f3850b3aa2c8c622ee28bb6368a9b8c2f78acbdef113a8...                 2
# 815  f4a585d3cdbfe2c01ff0881593d052a3d995635e2424fd...                 2
# 827  f8aba81163cc5ecf227699690d0b9b3707360f3ab5061b...                 2
# 828  f9ea5e817d10c1450d85bc1429dfc554afae89ba88e035...                 2
#
#     fall_position                              course_name
# ...

# %%
#убираем задвоения
fall_first_pr_no_repeats = fall_melted_first_pr_df.drop_duplicates(['id', 'course_name']).groupby('course_name').agg(
        total_students=('id', 'count'),
        student_ids=('id', list)
    )

# %%
fall_first_pr_final = fall_first_pr_no_repeats.reset_index()

# %%
fall_first_pr_final
# Out:
#                                           course_name  total_students  \
# 0                            Self-supervised Learning              18
# 1                         Statistical Learning Theory              26
# 2              Байесовские методы в машинном обучении              31
# 3                    Безопасность компьютерных систем              18
# 4                         Введение в платформы данных              21
# 5              Генеративные модели на основе диффузии               3
# 6   Генеративные модели на основе диффузии / Diffu...              10
# 7        Глубинное обучение в анализе графовых данных               3
# 8                Глубинное обучение в обработке звука              28
# 9             Глубинное обучение для текстовых данных              30
# 10                                      Дизайн систем              43
# 11                             Операционные системы 2              18
# ...

# %%
fall_first_pr_final['places'] = 30
fall_first_pr_final.loc[fall_first_pr_final['course_name'].isin(['Количественные финансы', 'Промышленное программирование на Haskell', 'Рекомендательные системы']) , 'places'] = 60
fall_first_pr_final.loc[fall_first_pr_final['course_name'] == 'Глубинное обучение в обработке звука' , 'places'] = 1000

# %%
fall_first_pr_final['dif'] = fall_first_pr_final['places'] - fall_first_pr_final['total_students']


overload = fall_first_pr_final[fall_first_pr_final['dif'] < 0]

# %% [markdown]
# Посмотрим, на какие курсы желающих оказалось больше, чем мест:

# %%
overload
# Out:
#                                course_name  total_students  \
# 2   Байесовские методы в машинном обучении              31
# 10                           Дизайн систем              43
# 18                  Распределенные системы              31
# 19                      Системы баз данных              81
# 24                                Язык SQL              37
#
#                                           student_ids  places  dif
# 2   [0b66b14bc0fae70f998b76662b70ae2006c2f1ae36353...      30   -1
# 10  [1b8da904a3533b19c6011c56ad02fcb2ab8e281e60d8e...      30  -13
# 18  [0371f1e9746b55e981d200dbc94929d95e6629295cbe4...      30   -1
# 19  [0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71...      30  -51
# 24  [0509d2ebe6f32b1240df06926f0f5583d8278d2ddb7a3...      30   -7

# %%
overloaded_courses = overload['course_name'].tolist()

# %%
course_assignments = []

for idx, row in fall_first_pr_final.iterrows():
    course = row['course_name']
    all_students = row['student_ids']
    places = row['places']

    if course in overload['course_name'].values:
        students_df = pd.DataFrame({'student_id': all_students})
        students_df['percentile'] = students_df['student_id'].map(
            dict(zip(df['id'], df['percentile']))
        )
        students_df = students_df.sort_values('percentile')
        lucky = students_df.head(places)['student_id'].tolist()
    else:
        lucky = all_students

    for i in lucky:
        course_assignments.append({
            'student_id': i,
            'course': course
        })
assignments_df = pd.DataFrame(course_assignments)
student_courses = assignments_df.groupby('student_id')['course'].apply(list).reset_index()
res = df[['id', 'courses_quantity', 'fall_1', 'fall_2']].copy()
res = res.merge(student_courses, left_on='id', right_on='student_id', how='left')

def get_courses(row):
    courses = row['course'] if isinstance(row['course'], list) else []
    course1 = None
    course2 = None
    if row['fall_1'] in courses:
        course1 = row['fall_1']
        courses.remove(row['fall_1'])

    if row['fall_2'] in courses and len(courses) > 0:
        course2 = row['fall_2']
        courses.remove(row['fall_2'])

    return pd.Series([course1, course2])

res[['course1', 'course2']] = res.apply(get_courses, axis=1)

final_df = res[['id', 'course1', 'course2', 'courses_quantity']].rename(columns={
    'id': 'ID',
    'courses_quantity': 'fall_course_num'
})

# %%
# (￣^￣)ゞ

# %% [markdown]
# Сверьте назначенные вами на первой волне курсы с эталоном. Для этого преобразуйте данные о назначенных курсах, приведя их в разрез "по студенту" (подробнее см в докстринге тест-функции), и передайте в функцию 'check_first_wave_assignments'. Если функция не выбросила Exception, то всё хорошо!
#
# **Обратите внимание: здесь обрабатывать детали условия касающиеся ответов `'???'` и `'-'` из требований к решению
# обрабатывать не нужно!**
#
# Трансформацию датасета (создание колонок `'course1'` и `'course2'`) советуем выделить в отдельную функцию, поскольку она понадобится вам далее при сдаче результатов в тестирующую систему.

# %%
# !wget  -O 'task_2_check.csv' -q 'https://www.dropbox.com/scl/fi/mxmp3b8ecssaei78sk4sp/task_2_check.csv?rlkey=uccmkaeo0zgv78pp3czs0s122&st=gr7s4m5u&dl=0'
check_df = pd.read_csv('./task_2_check.csv')

# %% [markdown]
# Если открытие check_df кинуло Exception, проверьте, что файл лежит в той же директории, из которой запущено ядро (kernel) вашего ноутбука (в его current working directory).
#
# *Стандартно файл должен скачиваться как раз туда, но вдруг у вас что-то пошло не так*

# %%
from pandas.testing import assert_frame_equal
from collections import Counter

def check_first_wave_assignments(assignments: pd.DataFrame) -> None:
    """
    assignments - pandas DataFrame с колонками ['ID', 'course1', 'course2', 'fall_course_num']. Одна строка -- один студент.
    - 'ID' - id студента (не объект индекса!)
    - 'course1', 'course2' - названия курсов, назначенные студенту в первую волну.
    Если один из курсов не назначен (вне зависимости от того, должен ли был быть назначен), то None.
    - 'fall_course_num' - число осенних курсов, которые должен выбрать студент.
    """

    def course_columns_to_set_column(row: pd.DataFrame):
        result = Counter()


        for column in ['course1', 'course2']:
            if (not pd.isna(row[column]) and row[column] is not None):
                result[row[column]] += 1

        return result


    ANSWER_SOURCE = './task_2_check.csv'

    ALTERNATIVES = {
        "cdb87f7b15495e514eb481230b44540c6b0cfeb347c991f06b1e361fcdef0c0b": [
            Counter({"Глубинное обучение для текстовых данных", "Байесовские методы в машинном обучении"}),
            Counter({"Глубинное обучение для текстовых данных", }),
        ],
        "6fa015d8846e21f4f79bac013b469a1e6e962fffd6121b4d9bcde3906275293e": [
            Counter({"Statistical Learning Theory", }),
            Counter({"Statistical Learning Theory", "Байесовские методы в машинном обучении"}),
        ]
    }

    answer_df = pd.read_csv(ANSWER_SOURCE)


    assignments = assignments.copy()


    assignments['course_set'] = assignments.apply(course_columns_to_set_column, axis=1)

    answer_df['course_set'] =  answer_df.apply(course_columns_to_set_column, axis=1)



    answer_df_common = answer_df[~answer_df['ID'].isin(ALTERNATIVES.keys())][['ID', 'course_set', 'fall_course_num']]

    assignments_common = assignments[~assignments['ID'].isin(ALTERNATIVES.keys())][['ID', 'course_set', 'fall_course_num']]

    answer_df_common = answer_df_common.set_index('ID').sort_index()
    assignments_common = assignments_common.set_index('ID').sort_index()


    assert_frame_equal(answer_df_common, assignments_common, check_dtype=False, check_names=False)

    for student in ALTERNATIVES:
        assert assignments[assignments['ID'] == student]['course_set'].isin(ALTERNATIVES[student]).iloc[0]
        assert answer_df[answer_df['ID'] == student]['fall_course_num'].iloc[0] == assignments[assignments['ID'] == student]['fall_course_num'].iloc[0]

# %%
check_first_wave_assignments(final_df)

# %% [markdown]
# #### 3. [1 балл] Проведите все три волны отбора студентов на курсы по выбору

# %%
losers = final_df[((final_df['fall_course_num'] == 1) & (final_df['course1'].isna()) | ((final_df['fall_course_num'] == 2) & (final_df['course1'].isna())) | ((final_df['fall_course_num'] == 2) & (final_df['course2'].isna())))]
losers
# Out:
#                                                     ID course1  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...    None
# 8    0509d2ebe6f32b1240df06926f0f5583d8278d2ddb7a3e...    None
# 22   0e60e06f5750f8601d5fb6f3097a7e77bde69d5dcbfdd0...    None
# 28   1352462a334f99c93e8946ce1d230d6876b827c1941ff2...    None
# 36   17ae6f2c8db9c21237594b791f3a43aaec4920d876d269...    None
# ..                                                 ...     ...
# 394  f33c3b48804f3cfa47ba7d92115fdf5b183dda29d167cf...    None
# 404  f677ce236730b156bb7ffdd7b512fd6f39a6f19586c49d...    None
# 406  f7f113333d13889093b621b953dd433c4fc32617f5ffa1...    None
# 410  f9ea5e817d10c1450d85bc1429dfc554afae89ba88e035...    None
# 411  fa7030f36c81ad8bc8924d8b7ad547cc037f6eb2f5a257...    None
#
#                          course2  fall_course_num
# 0                           None                1
# 8                           None                1
# 22                          None                1
# ...

# %%
second_priority = (
    ((fall_melted_df['fall_position'] == 'fall_3') & (fall_melted_df['courses_quantity'] == 2)) |
    ((fall_melted_df['fall_position'] == 'fall_2') & (fall_melted_df['courses_quantity'] == 1))
)

# %%
fall_melted_second_pr_df =  fall_melted_df[(second_priority & fall_melted_df['id'].isin(losers['ID']))].dropna(subset=['course_name'])
fall_melted_second_pr_df
# Out:
#                                                      id  courses_quantity  \
# 418   0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...                 1
# 426   0509d2ebe6f32b1240df06926f0f5583d8278d2ddb7a3e...                 1
# 440   0e60e06f5750f8601d5fb6f3097a7e77bde69d5dcbfdd0...                 1
# 446   1352462a334f99c93e8946ce1d230d6876b827c1941ff2...                 1
# 454   17ae6f2c8db9c21237594b791f3a43aaec4920d876d269...                 1
# ...                                                 ...               ...
# 829   fa7030f36c81ad8bc8924d8b7ad547cc037f6eb2f5a257...                 1
# 977   532a78c1cc336e7ecb1d4189f1e2498d81fa1094a4dc66...                 2
# 1036  6fa015d8846e21f4f79bac013b469a1e6e962fffd6121b...                 2
# 1050  776f50522ff3139728cb2ee5721708308c8555d36f4db6...                 2
# 1246  f9ea5e817d10c1450d85bc1429dfc554afae89ba88e035...                 2
#
#      fall_position                                        course_name
# ...

# %%
fall_second_pr_no_repeats = (
    fall_melted_second_pr_df
    .drop_duplicates(['id', 'course_name'])
    .query('course_name not in @overloaded_courses')
    .groupby('course_name')
    .agg(
        total_students=('id', 'count'),
        student_ids=('id', list)
    )
    .reset_index()
)
fall_second_pr_no_repeats
# Out:
#                                           course_name  total_students  \
# 0                         Statistical Learning Theory               2
# 1                    Безопасность компьютерных систем               4
# 2                         Введение в платформы данных               1
# 3   Генеративные модели на основе диффузии / Diffu...               1
# 4             Глубинное обучение для текстовых данных               2
# 5                              Операционные системы 2              12
# 6                       Основы информационного поиска               4
# 7                  Основы разработки компьютерных игр               2
# 8   Принятие решений в условиях риска и неопределе...               3
# 9                      Разработка микросервисов на Go              18
# 10                    Функциональное программирование               2
# 11       Эксплуатация и надёжность программных систем               2
# ...

# %%
fall_second_pr_final = pd.merge(fall_second_pr_no_repeats, fall_first_pr_final[['course_name', 'dif']], on='course_name', how='left').fillna(30)
fall_second_pr_final
# Out:
#                                           course_name  total_students  \
# 0                         Statistical Learning Theory               2
# 1                    Безопасность компьютерных систем               4
# 2                         Введение в платформы данных               1
# 3   Генеративные модели на основе диффузии / Diffu...               1
# 4             Глубинное обучение для текстовых данных               2
# 5                              Операционные системы 2              12
# 6                       Основы информационного поиска               4
# 7                  Основы разработки компьютерных игр               2
# 8   Принятие решений в условиях риска и неопределе...               3
# 9                      Разработка микросервисов на Go              18
# 10                    Функциональное программирование               2
# 11       Эксплуатация и надёжность программных систем               2
# ...

# %%
fall_second_pr_final = fall_second_pr_final[fall_second_pr_final['dif'] > 0]
fall_second_pr_final['diff'] = fall_second_pr_final['dif'] - fall_second_pr_final['total_students']
fall_second_pr_final
# Out:
# /tmp/ipython-input-3103386206.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fall_second_pr_final['diff'] = fall_second_pr_final['dif'] - fall_second_pr_final['total_students']
#                                           course_name  total_students  \
# 0                         Statistical Learning Theory               2
# 1                    Безопасность компьютерных систем               4
# 2                         Введение в платформы данных               1
# 3   Генеративные модели на основе диффузии / Diffu...               1
# 5                              Операционные системы 2              12
# 6                       Основы информационного поиска               4
# ...

# %%
fall_second_pr_overload = fall_second_pr_final[fall_second_pr_final['diff'] < 0]
fall_second_pr_overload
# Out:
#                       course_name  total_students  \
# 9  Разработка микросервисов на Go              18
#
#                                          student_ids  dif  diff
# 9  [0e60e06f5750f8601d5fb6f3097a7e77bde69d5dcbfdd...   17    -1

# %%
overloaded_courses_2 = fall_second_pr_overload['course_name'].tolist()
overloaded_courses = overloaded_courses + overloaded_courses_2
overloaded_courses
# Out:
# ['Байесовские методы в машинном обучении',
#  'Дизайн систем',
#  'Распределенные системы',
#  'Системы баз данных',
#  'Язык SQL',
#  'Разработка микросервисов на Go']

# %%
course_assignments = []

for idx, row in fall_second_pr_final.iterrows():
    course = row['course_name']
    all_students = row['student_ids']
    places = row['dif']

    if course in fall_second_pr_overload['course_name'].values:
        students_df = pd.DataFrame({'student_id': all_students})
        students_df['percentile'] = students_df['student_id'].map(
            dict(zip(df['id'], df['percentile']))
        )
        students_df = students_df.sort_values('percentile')
        lucky = students_df.head(places)['student_id'].tolist()
    else:
        lucky = all_students

    for i in lucky:
        course_assignments.append({
            'student_id': i,
            'course': course
        })
assignments_df = pd.DataFrame(course_assignments)
student_courses = assignments_df.groupby('student_id')['course'].apply(list).reset_index()
res = df[df['id'].isin(losers['ID'])][['id', 'courses_quantity', 'fall_2', 'fall_3']].copy()
res = res.merge(student_courses, left_on='id', right_on='student_id', how='left')

def get_courses(row):
    courses = row['course'] if isinstance(row['course'], list) else []

    course1 = None
    course2 = None
    max_courses = int(row['courses_quantity'])
    if max_courses == 1:
      if row['fall_2'] in courses:
        course1 = row['fall_2']
        courses.remove(row['fall_2'])
    else:
      if final_df[final_df['ID'] == row['id']].iloc[0]['course1'] is None:
        if row['fall_3'] in courses:
          course1 = row['fall_3']
          courses.remove(row['fall_3'])
      else:
        if row['fall_3'] in courses:
          course2 = row['fall_3']
          courses.remove(row['fall_3'])

    return pd.Series([course1, course2])

res[['course1', 'course2']] = res.apply(get_courses, axis=1)

final_df2 = res[['id', 'course1', 'course2', 'courses_quantity']].rename(columns={
    'id': 'ID',
    'courses_quantity': 'fall_course_num'
})

# %%
final_df2
# Out:
#                                                    ID  \
# 0   0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1   0509d2ebe6f32b1240df06926f0f5583d8278d2ddb7a3e...
# 2   0e60e06f5750f8601d5fb6f3097a7e77bde69d5dcbfdd0...
# 3   1352462a334f99c93e8946ce1d230d6876b827c1941ff2...
# 4   17ae6f2c8db9c21237594b791f3a43aaec4920d876d269...
# ..                                                ...
# 69  f33c3b48804f3cfa47ba7d92115fdf5b183dda29d167cf...
# 70  f677ce236730b156bb7ffdd7b512fd6f39a6f19586c49d...
# 71  f7f113333d13889093b621b953dd433c4fc32617f5ffa1...
# 72  f9ea5e817d10c1450d85bc1429dfc554afae89ba88e035...
# 73  fa7030f36c81ad8bc8924d8b7ad547cc037f6eb2f5a257...
#
#                              course1 course2  fall_course_num
# 0                               None    None                1
# 1        Statistical Learning Theory    None                1
# 2                               None    None                1
# 3        Введение в платформы данных    None                1
# ...

# %%
final_df_merged = final_df.combine_first(final_df2)
final_df_merged
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
# ..                                                 ...
# 413  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...
# 414  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...
# 415  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...
# 416  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...
# 417  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...
#
#                                   course1                   course2  \
# 0                                    None                      None
# 1    Глубинное обучение в обработке звука  Self-supervised Learning
# 2             Statistical Learning Theory                      None
# ...

# %%
final_df_merged[final_df_merged['course1'].isna()]
# Out:
#                                                     ID course1  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...    None
# 8    0509d2ebe6f32b1240df06926f0f5583d8278d2ddb7a3e...    None
# 22   0e60e06f5750f8601d5fb6f3097a7e77bde69d5dcbfdd0...    None
# 36   17ae6f2c8db9c21237594b791f3a43aaec4920d876d269...    None
# 57   22f1e637ae66b9b44455c0957867311e24bc58e6756eaa...    None
# ..                                                 ...     ...
# 394  f33c3b48804f3cfa47ba7d92115fdf5b183dda29d167cf...     NaN
# 404  f677ce236730b156bb7ffdd7b512fd6f39a6f19586c49d...     NaN
# 406  f7f113333d13889093b621b953dd433c4fc32617f5ffa1...     NaN
# 410  f9ea5e817d10c1450d85bc1429dfc554afae89ba88e035...     NaN
# 411  fa7030f36c81ad8bc8924d8b7ad547cc037f6eb2f5a257...     NaN
#
#                          course2  fall_course_num
# 0                           None                1
# 8                           None                1
# 22                          None                1
# ...

# %%
final_df_merged = pd.merge(final_df, final_df2, on='ID', how='outer')
final_df_merged['course1'] = final_df_merged.apply(lambda x: x['course1_x'] if pd.notna(x['course1_x']) else x['course1_y'], axis = 1)
final_df_merged['course2'] = final_df_merged.apply(lambda x: x['course2_x'] if pd.notna(x['course2_x']) else x['course2_y'], axis = 1)
final_df_merged['fall_course_num'] = final_df_merged.apply(lambda x: x['fall_course_num_x'] if pd.notna(x['fall_course_num_x']) else x['fall_course_num_y'], axis = 1)
final_df_merged = final_df_merged[['ID', 'course1', 'course2', 'fall_course_num']]
final_df_merged
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
# ..                                                 ...
# 413  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...
# 414  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...
# 415  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...
# 416  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...
# 417  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...
#
#                                   course1                   course2  \
# 0                                    None                      None
# 1    Глубинное обучение в обработке звука  Self-supervised Learning
# 2             Statistical Learning Theory                       NaN
# ...

# %%
losers_2 = final_df_merged[final_df_merged['course1'].isna() & final_df_merged['fall_course_num'] == 1]

# %%
losers_2
# Out:
#                                                     ID course1 course2  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...    None    None
# 22   0e60e06f5750f8601d5fb6f3097a7e77bde69d5dcbfdd0...    None    None
# 44   1a5edbf8181b2d2bde6b42dbd51c8618796758682d3753...    None    None
# 49   1d613ea9345f97f01a079aa01f5c452b12a8d1bee7f02c...    None    None
# 51   1ebed7a96b21d1ce0a579e461a0bd60155a0970421640e...    None    None
# 56   219253cbd3ac1bb9967100ebef6acf9eaafaf601c61ff0...    None    None
# 71   2ab682d14b59d373439d0c102092e2f9e7e9a72d970e8a...    None    None
# 74   2dc24dc9f0746a61093443321c0b5fe1ec00b84161af9c...    None    None
# 110  42ef32b37d66a14a97548fbc4ef487bc7bb4ab9f53cf0d...    None    None
# 112  43bf2fec8d21569f8ccd23cb210c678a5b7592df421da3...    None    None
# 131  4ccf2c54e9812d4af34a8e4ca68bd98966a9178ed4f854...    None    None
# 176  652ee3ccbe60a66f84890fc4506e3111e722b92ad6aa03...    None    None
# ...

# %%
third_priority = (
    ((fall_melted_df['fall_position'] == 'fall_3') & (fall_melted_df['courses_quantity'] == 1))
)

# %%
fall_melted_third_pr_df =  fall_melted_df[(third_priority & fall_melted_df['id'].isin(losers_2['ID']))].dropna(subset=['course_name'])
fall_melted_third_pr_df
# Out:
#                                                      id  courses_quantity  \
# 836   0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...                 1
# 858   0e60e06f5750f8601d5fb6f3097a7e77bde69d5dcbfdd0...                 1
# 880   1a5edbf8181b2d2bde6b42dbd51c8618796758682d3753...                 1
# 885   1d613ea9345f97f01a079aa01f5c452b12a8d1bee7f02c...                 1
# 887   1ebed7a96b21d1ce0a579e461a0bd60155a0970421640e...                 1
# 892   219253cbd3ac1bb9967100ebef6acf9eaafaf601c61ff0...                 1
# 907   2ab682d14b59d373439d0c102092e2f9e7e9a72d970e8a...                 1
# 910   2dc24dc9f0746a61093443321c0b5fe1ec00b84161af9c...                 1
# 946   42ef32b37d66a14a97548fbc4ef487bc7bb4ab9f53cf0d...                 1
# 948   43bf2fec8d21569f8ccd23cb210c678a5b7592df421da3...                 1
# 967   4ccf2c54e9812d4af34a8e4ca68bd98966a9178ed4f854...                 1
# 1012  652ee3ccbe60a66f84890fc4506e3111e722b92ad6aa03...                 1
# ...

# %%
fall_third_pr_no_repeats = (
    fall_melted_third_pr_df
    .drop_duplicates(['id', 'course_name'])
    .query('course_name not in @overloaded_courses')
    .groupby('course_name')
    .agg(
        total_students=('id', 'count'),
        student_ids=('id', list)
    )
    .reset_index()
)
fall_third_pr_no_repeats
# Out:
#                         course_name  total_students  \
# 0  Безопасность компьютерных систем               1
# 1       Введение в платформы данных               1
# 2            Операционные системы 2               2
# 3       Основы тензорных вычислений               1
# 4       Язык программирования Scala               1
#
#                                          student_ids
# 0  [2dc24dc9f0746a61093443321c0b5fe1ec00b84161af9...
# 1  [f677ce236730b156bb7ffdd7b512fd6f39a6f19586c49...
# 2  [1a5edbf8181b2d2bde6b42dbd51c8618796758682d375...
# 3  [4ccf2c54e9812d4af34a8e4ca68bd98966a9178ed4f85...
# 4  [1ebed7a96b21d1ce0a579e461a0bd60155a0970421640...

# %%
fall_third_pr_final = pd.merge(fall_third_pr_no_repeats, fall_second_pr_final[['course_name', 'diff']], on='course_name', how='left').fillna(30)
fall_third_pr_final
# Out:
#                         course_name  total_students  \
# 0  Безопасность компьютерных систем               1
# 1       Введение в платформы данных               1
# 2            Операционные системы 2               2
# 3       Основы тензорных вычислений               1
# 4       Язык программирования Scala               1
#
#                                          student_ids  diff
# 0  [2dc24dc9f0746a61093443321c0b5fe1ec00b84161af9...   8.0
# 1  [f677ce236730b156bb7ffdd7b512fd6f39a6f19586c49...   8.0
# 2  [1a5edbf8181b2d2bde6b42dbd51c8618796758682d375...   0.0
# 3  [4ccf2c54e9812d4af34a8e4ca68bd98966a9178ed4f85...  30.0
# 4  [1ebed7a96b21d1ce0a579e461a0bd60155a0970421640...  28.0

# %%
fall_third_pr_final = fall_third_pr_final[fall_third_pr_final['diff'] > 0]
fall_third_pr_final['difff'] = fall_third_pr_final['diff'] - fall_third_pr_final['total_students']
fall_third_pr_final
# Out:
# /tmp/ipython-input-2248040491.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fall_third_pr_final['difff'] = fall_third_pr_final['diff'] - fall_third_pr_final['total_students']
#                         course_name  total_students  \
# 0  Безопасность компьютерных систем               1
# 1       Введение в платформы данных               1
# 3       Основы тензорных вычислений               1
# 4       Язык программирования Scala               1
#
#                                          student_ids  diff  difff
# 0  [2dc24dc9f0746a61093443321c0b5fe1ec00b84161af9...   8.0    7.0
# 1  [f677ce236730b156bb7ffdd7b512fd6f39a6f19586c49...   8.0    7.0
# 3  [4ccf2c54e9812d4af34a8e4ca68bd98966a9178ed4f85...  30.0   29.0
# ...

# %%
fall_third_pr_overload = fall_third_pr_final[fall_third_pr_final['difff'] < 0]
fall_third_pr_overload
# Out:
# Empty DataFrame
# Columns: [course_name, total_students, student_ids, diff, difff]
# Index: []

# %%
course_assignments = []

for idx, row in fall_third_pr_final.iterrows():
    course = row['course_name']
    all_students = row['student_ids']
    places = row['diff']

    if course in fall_third_pr_overload['course_name'].values:
        students_df = pd.DataFrame({'student_id': all_students})
        students_df['percentile'] = students_df['student_id'].map(
            dict(zip(df['id'], df['percentile']))
        )
        students_df = students_df.sort_values('percentile')
        lucky = students_df.head(places)['student_id'].tolist()
    else:
        lucky = all_students

    for i in lucky:
        course_assignments.append({
            'student_id': i,
            'course': course
        })
assignments_df = pd.DataFrame(course_assignments)
student_courses = assignments_df.groupby('student_id')['course'].apply(list).reset_index()
res = df[df['id'].isin(losers_2['ID'])][['id', 'courses_quantity', 'fall_3']].copy()
res = res.merge(student_courses, left_on='id', right_on='student_id', how='left')

def get_courses(row):
    courses = row['course'] if isinstance(row['course'], list) else []

    course1 = None
    course2 = None
    max_courses = int(row['courses_quantity'])
    if max_courses == 1:
      if row['fall_3'] in courses:
        course1 = row['fall_3']
        courses.remove(row['fall_3'])
    return pd.Series([course1, course2])

res[['course1', 'course2']] = res.apply(get_courses, axis=1)

final_df3 = res[['id', 'course1', 'course2', 'courses_quantity']].rename(columns={
    'id': 'ID',
    'courses_quantity': 'fall_course_num'
})

# %%
final_df3
# Out:
#                                                    ID  \
# 0   0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1   0e60e06f5750f8601d5fb6f3097a7e77bde69d5dcbfdd0...
# 2   1a5edbf8181b2d2bde6b42dbd51c8618796758682d3753...
# 3   1d613ea9345f97f01a079aa01f5c452b12a8d1bee7f02c...
# 4   1ebed7a96b21d1ce0a579e461a0bd60155a0970421640e...
# 5   219253cbd3ac1bb9967100ebef6acf9eaafaf601c61ff0...
# 6   2ab682d14b59d373439d0c102092e2f9e7e9a72d970e8a...
# 7   2dc24dc9f0746a61093443321c0b5fe1ec00b84161af9c...
# 8   42ef32b37d66a14a97548fbc4ef487bc7bb4ab9f53cf0d...
# 9   43bf2fec8d21569f8ccd23cb210c678a5b7592df421da3...
# 10  4ccf2c54e9812d4af34a8e4ca68bd98966a9178ed4f854...
# 11  652ee3ccbe60a66f84890fc4506e3111e722b92ad6aa03...
# 12  70b7847978323ede047ee884261c905e192cb5afff2a84...
# 13  70b814cd0904633fdb88bd6e383a9f0ff8120c13b9c087...
# 14  7c0f8e5a7a5d8a0ef1a53d656cf6e7664a662bad79d55d...
# 15  ba6aeec35c518ef0ef22a92dff1e65d42735cd7f9cd54b...
# ...

# %%
final_df_merged1 = pd.merge(final_df_merged, final_df3, on='ID', how='outer')
final_df_merged1['course1'] = final_df_merged1.apply(lambda x: x['course1_x'] if pd.notna(x['course1_x']) else x['course1_y'], axis = 1)
final_df_merged1['course2'] = final_df_merged1.apply(lambda x: x['course2_x'] if pd.notna(x['course2_x']) else x['course2_y'], axis = 1)
final_df_merged1['fall_course_num'] = final_df_merged1.apply(lambda x: x['fall_course_num_x'] if pd.notna(x['fall_course_num_x']) else x['fall_course_num_y'], axis = 1)
final_df_merged1 = final_df_merged1[['ID', 'course1', 'course2', 'fall_course_num']]
final_df_merged1
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
# ..                                                 ...
# 413  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...
# 414  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...
# 415  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...
# 416  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...
# 417  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...
#
#                                   course1                   course2  \
# 0                                    None                      None
# 1    Глубинное обучение в обработке звука  Self-supervised Learning
# 2             Statistical Learning Theory                       NaN
# ...

# %%
df_done = final_df_merged1.copy()
df_done.loc[df_done['course1'].isna(), 'course1'] = '???'
df_done.loc[df_done['fall_course_num'] == 1, 'course2'] = '-'

# %%
df_done.loc[df_done['course2'].isna(), 'course2'] = '???'
df_done
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
# ..                                                 ...
# 413  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...
# 414  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...
# 415  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...
# 416  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...
# 417  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...
#
#                                   course1                   course2  \
# 0                                     ???                         -
# 1    Глубинное обучение в обработке звука  Self-supervised Learning
# 2             Statistical Learning Theory                         -
# ...

# %%
df_done.to_csv('res_fall.csv', index=False)
from google.colab import files
files.download('res_fall.csv')

# %%
# (￣^￣)ゞ

# %% [markdown]
# **Отправьте свой файл res_fall.csv в [Я.контест](https://new.contest.yandex.ru/contests/89154/start) и прикрепите/укажите ниже ваш никнейм и id успешной посылки.**
#
# никнейм: aavoronova_1@edu.hse.ru
#
# id посылки: 156913173

# %% [markdown]
# *Дисклеймер:*
#
# Успешная посылка в контесте является **обязательным** условием получения полного балла за этот (и следующий) пункт. Если добиться успешной посылки не удастся, баллы будут выставляться на усмотрение проверяюшего.
#
# При этом ОК в контесте не гарантирует полный балл. Оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# ### 4. [1 балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
spring_melted_df = df[['id', 'courses_quantity', 'spring_1', 'spring_2', 'spring_3']].melt(
    id_vars=['id', 'courses_quantity'],
    value_vars=['spring_1', 'spring_2', 'spring_3'],
    var_name='spring_position',
    value_name='course_name'
)
spring_melted_df
# Out:
#                                                      id  courses_quantity  \
# 0     0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...                 1
# 1     01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...                 2
# 2     01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...                 1
# 3     027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...                 1
# 4     0371f1e9746b55e981d200dbc94929d95e6629295cbe43...                 1
# ...                                                 ...               ...
# 1249  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...                 1
# 1250  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...                 1
# 1251  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...                 1
# 1252  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...                 1
# 1253  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...                 1
#
#      spring_position                               course_name
# ...

# %%
spring_melted = spring_melted_df.merge(df[['id', 'is_ml_student']], on='id', how='left')
spring_melted['forbidden'] = (
    (spring_melted['is_ml_student'] == 1) &
    (spring_melted['course_name'] == 'Машинное обучение 2')
)
spring_melted
# Out:
#                                                      id  courses_quantity  \
# 0     0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...                 1
# 1     01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...                 2
# 2     01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...                 1
# 3     027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...                 1
# 4     0371f1e9746b55e981d200dbc94929d95e6629295cbe43...                 1
# ...                                                 ...               ...
# 1249  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...                 1
# 1250  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...                 1
# 1251  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...                 1
# 1252  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...                 1
# 1253  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...                 1
#
#      spring_position                               course_name  is_ml_student  \
# ...

# %% [markdown]
# Посмотрим на наших нарушителей:

# %%
spring_melted[spring_melted['forbidden'] == 1]
# Out:
#                                                      id  courses_quantity  \
# 1020  6a43e43c97292ddc20ee6204067168247e89eb0344adea...                 1
# 1052  7935540b095acdf82e4baf21202af7afaf27e4ec193766...                 1
#
#      spring_position          course_name  is_ml_student  forbidden
# 1020        spring_3  Машинное обучение 2            1.0       True
# 1052        spring_3  Машинное обучение 2            1.0       True

# %% [markdown]
# Видим, что все нарушители выбрали запрещенное МО2 только третьим приоритетом, значит сдвигать приориеты некуда. То есть просто поставим им вместо их выбора для "spring_3" пропуск

# %%
spring_melted.loc[spring_melted['forbidden'] == 1, 'course_name'] = ''

# %%
spring_melted[spring_melted['forbidden'] == 1]
# Out:
#                                                      id  courses_quantity  \
# 1020  6a43e43c97292ddc20ee6204067168247e89eb0344adea...                 1
# 1052  7935540b095acdf82e4baf21202af7afaf27e4ec193766...                 1
#
#      spring_position course_name  is_ml_student  forbidden
# 1020        spring_3                        1.0       True
# 1052        spring_3                        1.0       True

# %%
first_priority = (
    (spring_melted_df['spring_position'] == 'spring_1') |
    ((spring_melted_df['spring_position'] == 'spring_2') & (spring_melted_df['courses_quantity'] == 2))
)

# %%
spring_melted_df.loc[spring_melted_df['course_name'].str.strip() == '', 'course_name'] = np.nan

# %%
spring_melted_first_pr_df =  spring_melted_df[first_priority].dropna(subset=['course_name'])
spring_melted_first_pr_df
# Out:
#                                                     id  courses_quantity  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...                 1
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...                 2
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...                 1
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...                 1
# 5    03e2f673656b6649c74d58431f7766aeba77c1dcc92fbe...                 1
# ..                                                 ...               ...
# 809  f0be509325f2e4dde7f85e32621a357db8dbd07522142f...                 2
# 813  f3850b3aa2c8c622ee28bb6368a9b8c2f78acbdef113a8...                 2
# 815  f4a585d3cdbfe2c01ff0881593d052a3d995635e2424fd...                 2
# 827  f8aba81163cc5ecf227699690d0b9b3707360f3ab5061b...                 2
# 828  f9ea5e817d10c1450d85bc1429dfc554afae89ba88e035...                 2
#
#     spring_position                              course_name
# ...

# %%
spring_first_pr_no_repeats = spring_melted_first_pr_df.drop_duplicates(['id', 'course_name']).groupby('course_name').agg(
        total_students=('id', 'count'),
        student_ids=('id', list)
    )

# %%
spring_first_pr_final = spring_first_pr_no_repeats.reset_index()
spring_first_pr_final
# Out:
#                                           course_name  total_students  \
# 0                                          Go от шада               1
# 1                                    Аналитика данных              25
# 2             Генеративные модели в машинном обучении               5
# 3   Генеративные модели в машинном обучении (углуб...              14
# 4            Глубинное обучение в естественных науках               2
# 5                          Децентрализованные системы              17
# 6             Дополнительные главы машинного обучения              20
# 7                              Количественные финансы               4
# 8                           Комбинаторная оптимизация               5
# 9                                   Компьютерные сети              65
# 10  Конфликты и кооперация (преподается на английс...               7
# 11                      Лингвистика для программистов               5
# ...

# %%
spring_first_pr_final['places'] = 30
spring_first_pr_final.loc[spring_first_pr_final['course_name'].isin(['Количественные финансы', 'Промышленное программирование на Haskell', 'Рекомендательные системы']) , 'places'] = 60
spring_first_pr_final.loc[spring_first_pr_final['course_name'] == 'Глубинное обучение в обработке звука' , 'places'] = 1000
spring_first_pr_final
# Out:
#                                           course_name  total_students  \
# 0                                          Go от шада               1
# 1                                    Аналитика данных              25
# 2             Генеративные модели в машинном обучении               5
# 3   Генеративные модели в машинном обучении (углуб...              14
# 4            Глубинное обучение в естественных науках               2
# 5                          Децентрализованные системы              17
# 6             Дополнительные главы машинного обучения              20
# 7                              Количественные финансы               4
# 8                           Комбинаторная оптимизация               5
# 9                                   Компьютерные сети              65
# 10  Конфликты и кооперация (преподается на английс...               7
# 11                      Лингвистика для программистов               5
# ...

# %%
spring_first_pr_final['dif'] = spring_first_pr_final['places'] - spring_first_pr_final['total_students']
overload_spring = spring_first_pr_final[spring_first_pr_final['dif'] < 0]
overload_spring
# Out:
#                                course_name  total_students  \
# 9                        Компьютерные сети              65
# 17                Обучение с подкреплением              49
# 26  Теория и практика онлайн-экспериментов              33
#
#                                           student_ids  places  dif
# 9   [0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71...      30  -35
# 17  [01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af...      30  -19
# 26  [0d8d98074c9402650e3b50c4291509ae59cbdbe73cd33...      30   -3

# %%
overloaded_courses_spring = overload_spring['course_name'].tolist()
overloaded_courses_spring
# Out:
# ['Компьютерные сети',
#  'Обучение с подкреплением',
#  'Теория и практика онлайн-экспериментов']

# %%
course_assignments = []

for idx, row in spring_first_pr_final.iterrows():
    course = row['course_name']
    all_students = row['student_ids']
    places = row['places']

    if course in overload_spring['course_name'].values:
        students_df = pd.DataFrame({'student_id': all_students})
        students_df['percentile'] = students_df['student_id'].map(
            dict(zip(df['id'], df['percentile']))
        )
        students_df = students_df.sort_values('percentile')
        lucky = students_df.head(places)['student_id'].tolist()
    else:
        lucky = all_students

    for i in lucky:
        course_assignments.append({
            'student_id': i,
            'course': course
        })
assignments_df = pd.DataFrame(course_assignments)
student_courses = assignments_df.groupby('student_id')['course'].apply(list).reset_index()
res = df[['id', 'courses_quantity', 'spring_1', 'spring_2']].copy()
res = res.merge(student_courses, left_on='id', right_on='student_id', how='left')

def get_courses(row):
    courses = row['course'] if isinstance(row['course'], list) else []

    course1 = None
    course2 = None

    if row['spring_1'] in courses:
        course1 = row['spring_1']
        courses.remove(row['spring_1'])

    if row['spring_2'] in courses and len(courses) > 0:
        course2 = row['spring_2']
        courses.remove(row['spring_2'])

    return pd.Series([course1, course2])

res[['course1', 'course2']] = res.apply(get_courses, axis=1)

final_df_spring = res[['id', 'course1', 'course2', 'courses_quantity']].rename(columns={
    'id': 'ID',
    'courses_quantity': 'spring_course_num'
})

# %%
final_df_spring
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
# ..                                                 ...
# 413  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...
# 414  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...
# 415  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...
# 416  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...
# 417  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...
#
#                                                course1  \
# 0                                                 None
# 1                                                 None
# 2                                Стохастический анализ
# 3                                     Аналитика данных
# ...

# %%
losers_spring = final_df_spring[((final_df_spring['spring_course_num'] == 1) & (final_df_spring['course1'].isna()) | ((final_df_spring['spring_course_num'] == 2) & (final_df_spring['course1'].isna())) | ((final_df_spring['spring_course_num'] == 2) & (final_df_spring['course2'].isna())))]
losers_spring
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
# 11   08036beac8f704653d8d9199d305f67de6631755707042...
# 12   0819727ae3da796c1e6fc10171bfacddebce325490b94a...
# ..                                                 ...
# 395  f3850b3aa2c8c622ee28bb6368a9b8c2f78acbdef113a8...
# 406  f7f113333d13889093b621b953dd433c4fc32617f5ffa1...
# 410  f9ea5e817d10c1450d85bc1429dfc554afae89ba88e035...
# 411  fa7030f36c81ad8bc8924d8b7ad547cc037f6eb2f5a257...
# 416  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...
#
#                                      course1  \
# 0                                       None
# 1                                       None
# 4                                       None
# 11                                      None
# 12                                      None
# ...

# %%
second_priority = (
    ((spring_melted_df['spring_position'] == 'spring_3') & (spring_melted_df['courses_quantity'] == 2)) |
    ((spring_melted_df['spring_position'] == 'spring_2') & (spring_melted_df['courses_quantity'] == 1))
)

# %%
spring_melted_second_pr_df =  spring_melted_df[(second_priority & spring_melted_df['id'].isin(losers_spring['ID']))].dropna(subset=['course_name'])
spring_melted_second_pr_df
# Out:
#                                                      id  courses_quantity  \
# 418   0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...                 1
# 440   0e60e06f5750f8601d5fb6f3097a7e77bde69d5dcbfdd0...                 1
# 474   219253cbd3ac1bb9967100ebef6acf9eaafaf601c61ff0...                 1
# 475   22f1e637ae66b9b44455c0957867311e24bc58e6756eaa...                 1
# 487   29b1507eb0e2b983d77f399ae0f741b30177880515722e...                 1
# 489   2ab682d14b59d373439d0c102092e2f9e7e9a72d970e8a...                 1
# 494   2ecddada077c7c1569c26987099460c755588661e8b628...                 1
# 508   372e990521df9488f677d38637768366b075e63821bb34...                 1
# 517   3d580df21f9ec9b262f3cd332894390e26e25d887f152c...                 1
# 533   46c7e108aaec281bcd5f953ba65c5d33d632f32a1ba204...                 1
# 573   5c5ec9578bcc882c10adcc2a05ce65c85554f1ea0404e8...                 1
# 575   5d74500c681e1d17d1cbcdc107d176e770df6342999cbd...                 1
# ...

# %%
spring_second_pr_no_repeats = (
    spring_melted_second_pr_df
    .drop_duplicates(['id', 'course_name'])
    .query('course_name not in @overloaded_courses_spring')
    .groupby('course_name')
    .agg(
        total_students=('id', 'count'),
        student_ids=('id', list)
    )
    .reset_index()
)
spring_second_pr_no_repeats
# Out:
#                                           course_name  total_students  \
# 0                                    Аналитика данных               2
# 1             Генеративные модели в машинном обучении               2
# 2   Генеративные модели в машинном обучении (углуб...               2
# 3                              Количественные финансы               2
# 4                       Лингвистика для программистов               1
# 5          Математические основы нейросетевых моделей               3
# 6                                 Машинное обучение 2               1
# 7                Методы сжатия и передачи медиаданных               2
# 8            Промышленное программирование на Haskell               1
# 9         Промышленное программирование на языке Java              11
# 10  Развёртывание ML-моделей в высоконагруженных с...               1
# 11                           Рекомендательные системы               1
# ...

# %%
spring_second_pr_final = pd.merge(spring_second_pr_no_repeats, spring_first_pr_final[['course_name', 'dif']], on='course_name', how='left')
spring_second_pr_final
# Out:
#                                           course_name  total_students  \
# 0                                    Аналитика данных               2
# 1             Генеративные модели в машинном обучении               2
# 2   Генеративные модели в машинном обучении (углуб...               2
# 3                              Количественные финансы               2
# 4                       Лингвистика для программистов               1
# 5          Математические основы нейросетевых моделей               3
# 6                                 Машинное обучение 2               1
# 7                Методы сжатия и передачи медиаданных               2
# 8            Промышленное программирование на Haskell               1
# 9         Промышленное программирование на языке Java              11
# 10  Развёртывание ML-моделей в высоконагруженных с...               1
# 11                           Рекомендательные системы               1
# ...

# %%
spring_second_pr_final = spring_second_pr_final[spring_second_pr_final['dif'] > 0]
spring_second_pr_final['diff'] = spring_second_pr_final['dif'] - spring_second_pr_final['total_students']
spring_second_pr_final
# Out:
#                                           course_name  total_students  \
# 0                                    Аналитика данных               2
# 1             Генеративные модели в машинном обучении               2
# 2   Генеративные модели в машинном обучении (углуб...               2
# 3                              Количественные финансы               2
# 4                       Лингвистика для программистов               1
# 5          Математические основы нейросетевых моделей               3
# 6                                 Машинное обучение 2               1
# 7                Методы сжатия и передачи медиаданных               2
# 8            Промышленное программирование на Haskell               1
# 9         Промышленное программирование на языке Java              11
# 10  Развёртывание ML-моделей в высоконагруженных с...               1
# 11                           Рекомендательные системы               1
# ...

# %%
spring_second_pr_overload = spring_second_pr_final[spring_second_pr_final['diff'] < 0]
spring_second_pr_overload
# Out:
# Empty DataFrame
# Columns: [course_name, total_students, student_ids, dif, diff]
# Index: []

# %%
course_assignments = []

for idx, row in spring_second_pr_final.iterrows():
    course = row['course_name']
    all_students = row['student_ids']
    places = row['dif']

    if course in spring_second_pr_overload['course_name'].values:
        students_df = pd.DataFrame({'student_id': all_students})
        students_df['percentile'] = students_df['student_id'].map(
            dict(zip(df['id'], df['percentile']))
        )
        students_df = students_df.sort_values('percentile')
        lucky = students_df.head(places)['student_id'].tolist()
    else:
        lucky = all_students

    for i in lucky:
        course_assignments.append({
            'student_id': i,
            'course': course
        })
assignments_df = pd.DataFrame(course_assignments)
student_courses = assignments_df.groupby('student_id')['course'].apply(list).reset_index()
res = df[df['id'].isin(losers_spring['ID'])][['id', 'courses_quantity', 'spring_2', 'spring_3']].copy()
res = res.merge(student_courses, left_on='id', right_on='student_id', how='left')

def get_courses(row):
    courses = row['course'] if isinstance(row['course'], list) else []

    course1 = None
    course2 = None
    max_courses = int(row['courses_quantity'])
    if max_courses == 1:
      if row['spring_2'] in courses:
        course1 = row['spring_2']
        courses.remove(row['spring_2'])
    else:
      if final_df_spring[final_df_spring['ID'] == row['id']].iloc[0]['course1'] is None:
        if row['spring_3'] in courses:
          course1 = row['spring_3']
          courses.remove(row['spring_3'])
      else:
        if row['spring_3'] in courses:
          course2 = row['spring_3']
          courses.remove(row['spring_3'])

    return pd.Series([course1, course2])

res[['course1', 'course2']] = res.apply(get_courses, axis=1)

final_df2_spring = res[['id', 'course1', 'course2', 'courses_quantity']].rename(columns={
    'id': 'ID',
    'courses_quantity': 'spring_course_num'
})

# %%
final_df2_spring
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 2    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
# 3    08036beac8f704653d8d9199d305f67de6631755707042...
# 4    0819727ae3da796c1e6fc10171bfacddebce325490b94a...
# ..                                                 ...
# 97   f3850b3aa2c8c622ee28bb6368a9b8c2f78acbdef113a8...
# 98   f7f113333d13889093b621b953dd433c4fc32617f5ffa1...
# 99   f9ea5e817d10c1450d85bc1429dfc554afae89ba88e035...
# 100  fa7030f36c81ad8bc8924d8b7ad547cc037f6eb2f5a257...
# 101  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...
#
#                                          course1  \
# 0                                           None
# 1     Математические основы нейросетевых моделей
# 2                                           None
# 3                                           None
# 4                                           None
# ...

# %%
final_df_merged_spring = final_df_spring.combine_first(final_df2_spring)
final_df_merged_spring
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
# ..                                                 ...
# 413  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...
# 414  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...
# 415  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...
# 416  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...
# 417  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...
#
#                                                course1  \
# 0                                                 None
# 1           Математические основы нейросетевых моделей
# 2                                Стохастический анализ
# 3                                     Аналитика данных
# ...

# %%
final_df_merged_spring[final_df_merged['course1'].isna()]
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 22   0e60e06f5750f8601d5fb6f3097a7e77bde69d5dcbfdd0...
# 44   1a5edbf8181b2d2bde6b42dbd51c8618796758682d3753...
# 49   1d613ea9345f97f01a079aa01f5c452b12a8d1bee7f02c...
# 51   1ebed7a96b21d1ce0a579e461a0bd60155a0970421640e...
# 56   219253cbd3ac1bb9967100ebef6acf9eaafaf601c61ff0...
# 71   2ab682d14b59d373439d0c102092e2f9e7e9a72d970e8a...
# 74   2dc24dc9f0746a61093443321c0b5fe1ec00b84161af9c...
# 110  42ef32b37d66a14a97548fbc4ef487bc7bb4ab9f53cf0d...
# 112  43bf2fec8d21569f8ccd23cb210c678a5b7592df421da3...
# 131  4ccf2c54e9812d4af34a8e4ca68bd98966a9178ed4f854...
# 176  652ee3ccbe60a66f84890fc4506e3111e722b92ad6aa03...
# 202  70b7847978323ede047ee884261c905e192cb5afff2a84...
# 203  70b814cd0904633fdb88bd6e383a9f0ff8120c13b9c087...
# 214  776f50522ff3139728cb2ee5721708308c8555d36f4db6...
# 224  7c0f8e5a7a5d8a0ef1a53d656cf6e7664a662bad79d55d...
# ...

# %%
final_df_merged_spring = pd.merge(final_df_spring, final_df2_spring, on='ID', how='outer')
final_df_merged_spring['course1'] = final_df_merged_spring.apply(lambda x: x['course1_x'] if pd.notna(x['course1_x']) else x['course1_y'], axis = 1)
final_df_merged_spring['course2'] = final_df_merged_spring.apply(lambda x: x['course2_x'] if pd.notna(x['course2_x']) else x['course2_y'], axis = 1)
final_df_merged_spring['spring_course_num'] = final_df_merged_spring.apply(lambda x: x['spring_course_num_x'] if pd.notna(x['spring_course_num_x']) else x['spring_course_num_y'], axis = 1)
final_df_merged_spring = final_df_merged_spring[['ID', 'course1', 'course2', 'spring_course_num']]
final_df_merged_spring
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
# ..                                                 ...
# 413  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...
# 414  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...
# 415  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...
# 416  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...
# 417  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...
#
#                                                course1  \
# 0                                                 None
# 1           Математические основы нейросетевых моделей
# 2                                Стохастический анализ
# 3                                     Аналитика данных
# ...

# %%
losers_2_spring = final_df_merged_spring[final_df_merged_spring['course1'].isna() & final_df_merged_spring['spring_course_num'] == 1]

# %%
losers_2_spring
# Out:
#                                                     ID course1 course2  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...    None    None
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...    None    None
# 11   08036beac8f704653d8d9199d305f67de6631755707042...    None    None
# 12   0819727ae3da796c1e6fc10171bfacddebce325490b94a...    None    None
# 26   11daff8d676cc1cd424d403804ff0b44caa6b22e3d56f8...    None    None
# 27   12cf8adb8993c25f276cfa029955814fe77b2b9de5464e...    None    None
# 42   1a09d5aeac4e288fe086cee1bd4fd5e6a5621e4f2a83a6...    None    None
# 43   1a265e9471b283ce9fb427a8935a1acfbd037c7915aee9...    None    None
# 46   1ac8c3290d194ea958a120a9546b449cb6a98272011a67...    None    None
# 49   1d613ea9345f97f01a079aa01f5c452b12a8d1bee7f02c...    None    None
# 52   2075180735f0273260529b9e83d13e7d680270c75aa24c...    None    None
# 56   219253cbd3ac1bb9967100ebef6acf9eaafaf601c61ff0...    None    None
# ...

# %%
third_priority = (
    ((spring_melted_df['spring_position'] == 'spring_3') & (fall_melted_df['courses_quantity'] == 1))
)

# %%
spring_melted_third_pr_df =  spring_melted_df[(third_priority & spring_melted_df['id'].isin(losers_2_spring['ID']))].dropna(subset=['course_name'])
spring_melted_third_pr_df
# Out:
#                                                      id  courses_quantity  \
# 836   0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...                 1
# 892   219253cbd3ac1bb9967100ebef6acf9eaafaf601c61ff0...                 1
# 905   29b1507eb0e2b983d77f399ae0f741b30177880515722e...                 1
# 907   2ab682d14b59d373439d0c102092e2f9e7e9a72d970e8a...                 1
# 912   2ecddada077c7c1569c26987099460c755588661e8b628...                 1
# 926   372e990521df9488f677d38637768366b075e63821bb34...                 1
# 935   3d580df21f9ec9b262f3cd332894390e26e25d887f152c...                 1
# 951   46c7e108aaec281bcd5f953ba65c5d33d632f32a1ba204...                 1
# 991   5c5ec9578bcc882c10adcc2a05ce65c85554f1ea0404e8...                 1
# 1012  652ee3ccbe60a66f84890fc4506e3111e722b92ad6aa03...                 1
# 1038  70b7847978323ede047ee884261c905e192cb5afff2a84...                 1
# 1153  bafc40852ed6add30a20a060d92c8394c37573bf4677fa...                 1
# ...

# %%
spring_third_pr_no_repeats = (
    spring_melted_third_pr_df
    .drop_duplicates(['id', 'course_name'])
    .query('course_name not in @overloaded_courses_spring')
    .groupby('course_name')
    .agg(
        total_students=('id', 'count'),
        student_ids=('id', list)
    )
    .reset_index()
)
spring_third_pr_no_repeats
# Out:
#                                    course_name  total_students  \
# 0  Промышленное программирование на языке Java               1
#
#                                          student_ids
# 0  [3d580df21f9ec9b262f3cd332894390e26e25d887f152...

# %%
spring_third_pr_final = pd.merge(spring_third_pr_no_repeats, spring_second_pr_final[['course_name', 'diff']], on='course_name', how='left').fillna(30)
spring_third_pr_final
# Out:
#                                    course_name  total_students  \
# 0  Промышленное программирование на языке Java               1
#
#                                          student_ids  diff
# 0  [3d580df21f9ec9b262f3cd332894390e26e25d887f152...    17

# %%
spring_third_pr_final = spring_third_pr_final[spring_third_pr_final['diff'] > 0]
spring_third_pr_final['difff'] = spring_third_pr_final['diff'] - spring_third_pr_final['total_students']
spring_third_pr_final
# Out:
#                                    course_name  total_students  \
# 0  Промышленное программирование на языке Java               1
#
#                                          student_ids  diff  difff
# 0  [3d580df21f9ec9b262f3cd332894390e26e25d887f152...    17     16

# %%
spring_third_pr_overload = spring_third_pr_final[spring_third_pr_final['difff'] < 0]
spring_third_pr_overload
# Out:
# Empty DataFrame
# Columns: [course_name, total_students, student_ids, diff, difff]
# Index: []

# %%
for idx, row in spring_third_pr_final.iterrows():
    course = row['course_name']
    all_students = row['student_ids']
    places = row['diff']

    if course in spring_third_pr_overload['course_name'].values:
        students_df = pd.DataFrame({'student_id': all_students})
        students_df['percentile'] = students_df['student_id'].map(
            dict(zip(df['id'], df['percentile']))
        )
        students_df = students_df.sort_values('percentile')
        lucky = students_df.head(places)['student_id'].tolist()
    else:
        lucky = all_students

    for i in lucky:
        course_assignments.append({
            'student_id': i,
            'course': course
        })
assignments_df = pd.DataFrame(course_assignments)
student_courses = assignments_df.groupby('student_id')['course'].apply(list).reset_index()
res = df[df['id'].isin(losers_2_spring['ID'])][['id', 'courses_quantity', 'spring_3']].copy()
res = res.merge(student_courses, left_on='id', right_on='student_id', how='left')

def get_courses(row):
    courses = row['course'] if isinstance(row['course'], list) else []

    course1 = None
    course2 = None
    max_courses = int(row['courses_quantity'])
    if max_courses == 1:
      if row['spring_3'] in courses:
        course1 = row['spring_3']
        courses.remove(row['spring_3'])
    return pd.Series([course1, course2])

res[['course1', 'course2']] = res.apply(get_courses, axis=1)

final_df3_spring = res[['id', 'course1', 'course2', 'courses_quantity']].rename(columns={
    'id': 'ID',
    'courses_quantity': 'spring_course_num'
})

# %%
final_df_merged1_spring = pd.merge(final_df_merged_spring, final_df3_spring, on='ID', how='outer')
final_df_merged1_spring['course1'] = final_df_merged1_spring.apply(lambda x: x['course1_x'] if pd.notna(x['course1_x']) else x['course1_y'], axis = 1)
final_df_merged1_spring['course2'] = final_df_merged1_spring.apply(lambda x: x['course2_x'] if pd.notna(x['course2_x']) else x['course2_y'], axis = 1)
final_df_merged1_spring['spring_course_num'] = final_df_merged1_spring.apply(lambda x: x['spring_course_num_x'] if pd.notna(x['spring_course_num_x']) else x['spring_course_num_y'], axis = 1)
final_df_merged1_spring = final_df_merged1_spring[['ID', 'course1', 'course2', 'spring_course_num']]
final_df_merged1_spring
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
# ..                                                 ...
# 413  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...
# 414  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...
# 415  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...
# 416  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...
# 417  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...
#
#                                                course1  \
# 0                                                 None
# 1           Математические основы нейросетевых моделей
# 2                                Стохастический анализ
# 3                                     Аналитика данных
# ...

# %%
df_done = final_df_merged1_spring.copy()
df_done.loc[df_done['course1'].isna(), 'course1'] = '???'
df_done.loc[df_done['spring_course_num'] == 1, 'course2'] = '-'

# %%
df_done.loc[df_done['course2'].isna(), 'course2'] = '???'
df_done
# Out:
#                                                     ID  \
# 0    0059ff585d5dd682c681c52e0bffb9d0c2a259d2a3f71c...
# 1    01d7c005dacd8c0be29bae8672b92be43c8cd0bd5b0af9...
# 2    01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...
# 3    027ed85baa13164987f5c30f6e4bdcb9c8f6566ca2d09d...
# 4    0371f1e9746b55e981d200dbc94929d95e6629295cbe43...
# ..                                                 ...
# 413  fd9e56667275c376fd4349cbc7d049bf77d0602a6b3aac...
# 414  fe90aa7a0896204cfb47d3fa8c5ee079a22a1f900b6755...
# 415  ff2b57429d0d45788e2e22cf0c13fe152ef7a8e41f480f...
# 416  ffe30e6b61eb3a819223305e77c276da9c373aa4a8763f...
# 417  ffe8d06cea1659050c082aaa85799104d7619ca0e2e500...
#
#                                                course1  \
# 0                                                  ???
# 1           Математические основы нейросетевых моделей
# 2                                Стохастический анализ
# 3                                     Аналитика данных
# ...

# %%
df_done.to_csv('res_spring.csv', index=False)
from google.colab import files
files.download('res_spring.csv')

# %%
# (￣^'￣)ゞ

# %% [markdown]
# **Отправьте свой файл res_spring.csv в [Я.контест](https://new.contest.yandex.ru/contests/89154/start) и прикрепите/укажите ниже ваш никнейм и id успешной посылки.**
#
# никнейм: aavoronova_1@edu.hse.ru
#
# id посылки: 156916408

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask, **туда же и продублируйте никнейм в Я.контесте и id успешных посылок**.

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:
